# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\NIKITA SURVE\Downloads\placement.csv")

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
import matplotlib.pyplot as plt
plt.scatter(df["cgpa"],df["package"])
plt.xlabel("CGPA")
plt.ylabel("Package")
# Out:
# Text(0, 0.5, 'Package')

# %%
x = df[['cgpa']]  #i/p
y = df[['package']]  #o/p

# %%
x.shape,y.shape
# Out:
# ((200, 1), (200, 1))

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.20,random_state = 42)

# %%
x_train.shape,x_test.shape
# Out:
# ((160, 1), (40, 1))

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
# train
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# train score
model.score(x_train,y_train)
# Out:
# 0.7758339025733345

# %%
# this is my bulk prediction
y_pred = model.predict(x_test)
# y_pred

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7730984312051673

# %%
model.predict([[6.89]]),model.predict([[5.66]])
# Out:
# C:\Users\NIKITA SURVE\AppData\Roaming\Python\Python314\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\NIKITA SURVE\AppData\Roaming\Python\Python314\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# (array([[2.92962016]]), array([[2.2232847]]))

# %%
model.predict([[5.66]])
# Out:
# C:\Users\NIKITA SURVE\AppData\Roaming\Python\Python314\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[2.2232847]])

# %%
model.predict([[9.0]])
# Out:
# C:\Users\NIKITA SURVE\AppData\Roaming\Python\Python314\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[4.14130132]])

# %%
#this is my bulk prediction
y_pred_test=model.predict(x_test)

# %%
y_test
# Out:
#      package
# 95      2.79
# 15      3.23
# 30      3.26
# 158     3.04
# 128     3.34
# 115     4.21
# 69      2.94
# 170     2.87
# 174     2.99
# 45      3.58
# 66      1.63
# 182     2.08
# 165     4.08
# 78      2.21
# 186     3.47
# 177     3.64
# 56      2.74
# 152     3.08
# 82      2.17
# 68      2.99
# 124     2.31
# 16      2.35
# 148     3.40
# 93      3.08
# 65      3.81
# 60      2.19
# 84      1.53
# 67      2.89
# 125     3.16
# 132     2.48
# 9       3.51
# 18      2.98
# 55      3.39
# 75      3.28
# 150     2.73
# 104     3.74
# 135     2.60
# 137     3.13
# 164     3.82
# 76      3.15

# %%
from sklearn.metrics import r2_score

# %%
#test acc
r2_score(y_test,y_pred_test)
# Out:
# 0.7730984312051673

# %%
#tran acc
#y_pred_train=model.predict(X_train)
#r2_score(y_train,y_pred_train)

# %%
import joblib

#save the model to a file
joblib.dump(model,"regression_model_joblib")
# Out:
# ['regression_model_joblib']

# %%
joblib_model.predict([[6.89]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 joblib_model.predict([[6.89]])
#
# NameError: name 'joblib_model' is not defined

# %% [raw]
# y = mx + c

# %%
c=model.intercept_
c
# Out:
# array([-1.02700694])

# %%
m=model.coef_
m
# Out:
# array([[0.57425647]])

# %%
#y=mx+c
y=m*6.89+c
y
# Out:
# array([[2.92962016]])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(x_train,model.predict(x_train),color="red")
